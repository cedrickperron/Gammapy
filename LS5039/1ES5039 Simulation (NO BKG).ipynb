# %%
# %matplotlib inline
import matplotlib.pyplot as plt



import numpy as np
from gammapy.irf import *
import astropy.units as u
from astropy.coordinates import SkyCoord, Angle
from regions import CircleSkyRegion
from gammapy.datasets import SpectrumDatasetOnOff, SpectrumDataset, Datasets
from gammapy.data import DataStore, EventList
from gammapy.makers import SpectrumDatasetMaker
from gammapy.modeling import Fit
from gammapy.modeling.models import (
    PowerLawSpectralModel,
    SkyModel,
)
from gammapy.makers import (
    MapDatasetMaker,
    SafeMaskMaker,
    SpectrumDatasetMaker,
    ReflectedRegionsBackgroundMaker,
    RingBackgroundMaker,
    ReflectedRegionsFinder,
    
)
from gammapy.maps import MapAxis, WcsNDMap, WcsGeom, Map, RegionNDMap
from gammapy.irf import load_cta_irfs
from gammapy.data import Observation
from gammapy.maps import MapAxis

from  gammapy.utils.random import get_random_state

source = "1ES1959"
data_store = DataStore.from_dir(f"/Users/cedrickperron/GAMMAPY/{source}")
hdu_table = data_store.hdu_table.read(f"/Users/cedrickperron/GAMMAPY/{source}/hdu-index.fits.gz")
obs_table = data_store.obs_table.read(f"/Users/cedrickperron/GAMMAPY/{source}/obs-index.fits.gz")
# Changing the path to the fits files in the HDU_table
hdu_table.remove_column("FILE_DIR")
hdu_table.add_column(f"/Users/cedrickperron/GAMMAPY/{source}", name="FILE_DIR")
hdu_table
# Out:
# <HDUIndexTable length=550>
# OBS_ID HDU_TYPE ...      HDU_NAME                   FILE_DIR
# int64   bytes6  ...      bytes20                     str36
# ------ -------- ... ----------------- ------------------------------------
#  37793   events ...            EVENTS /Users/cedrickperron/GAMMAPY/1ES1959
#  37793      gti ...               GTI /Users/cedrickperron/GAMMAPY/1ES1959
#  37793     aeff ...    EFFECTIVE AREA /Users/cedrickperron/GAMMAPY/1ES1959
#  37793    edisp ... ENERGY DISPERSION /Users/cedrickperron/GAMMAPY/1ES1959
#  37793      psf ...               PSF /Users/cedrickperron/GAMMAPY/1ES1959
#  37890   events ...            EVENTS /Users/cedrickperron/GAMMAPY/1ES1959
#  37890      gti ...               GTI /Users/cedrickperron/GAMMAPY/1ES1959
#  37890     aeff ...    EFFECTIVE AREA /Users/cedrickperron/GAMMAPY/1ES1959
#  37890    edisp ... ENERGY DISPERSION /Users/cedrickperron/GAMMAPY/1ES1959
#  37890      psf ...               PSF /Users/cedrickperron/GAMMAPY/1ES1959
#    ...      ... ...               ...                                  ...
#  78664   events ...            EVENTS /Users/cedrickperron/GAMMAPY/1ES1959
#  78664      gti ...               GTI /Users/cedrickperron/GAMMAPY/1ES1959
#  78664     aeff ...    EFFECTIVE AREA /Users/cedrickperron/GAMMAPY/1ES1959
#  78664    edisp ... ENERGY DISPERSION /Users/cedrickperron/GAMMAPY/1ES1959
#  78664      psf ...               PSF /Users/cedrickperron/GAMMAPY/1ES1959
#  81868   events ...            EVENTS /Users/cedrickperron/GAMMAPY/1ES1959
#  81868      gti ...               GTI /Users/cedrickperron/GAMMAPY/1ES1959
#  81868     aeff ...    EFFECTIVE AREA /Users/cedrickperron/GAMMAPY/1ES1959
#  81868    edisp ... ENERGY DISPERSION /Users/cedrickperron/GAMMAPY/1ES1959
#  81868      psf ...               PSF /Users/cedrickperron/GAMMAPY/1ES1959

# %%
data_store.obs_table
data_store.hdu_table = hdu_table

data_store.hdu_table
obs_id = data_store.obs_table["OBS_ID"]



# Note NO HDU of HDU_TYPE = bkg. Write print(hdu_table) and you will see that there is no bkg.
observations = data_store.get_observations(obs_id)
# Out:
# No HDU found matching: OBS_ID = 37793, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 37890, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 38018, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 38019, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 41713, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 41960, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 41961, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 41962, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 41963, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 41964, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 42073, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 53469, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 53470, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 53471, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 53472, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 53473, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 53504, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 53535, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 61991, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 61992, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 61993, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 62046, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 62082, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 62109, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 51601, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 51602, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 57377, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 57379, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 57857, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 58002, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 58003, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 58026, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 58279, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 62596, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 62672, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 62673, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 62674, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 62675, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 62676, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 62677, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 62695, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 62697, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 62720, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 62748, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 62773, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 62793, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 62822, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 62884, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 62917, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 62993, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 62994, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 63006, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 63171, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 63767, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 63854, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 63928, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 63998, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 64085, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 64182, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 64643, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 64694, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 68985, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 68986, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 69068, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 69140, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 69192, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 69233, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 77945, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 78572, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 78573, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 78574, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 78576, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 78596, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 78597, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 78598, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 78599, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 78613, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 78614, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 78615, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 78616, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 78647, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 78648, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 78666, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 78705, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 78760, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 79008, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 79009, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 79051, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 79082, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 79107, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 81841, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 81891, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 82417, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 82514, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 37991, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 37992, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 41470, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 41472, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 41478, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 62015, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 62016, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 62017, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 62018, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 62137, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 62162, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 64518, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 69022, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 78168, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 78664, HDU_TYPE = bkg, HDU_CLASS = None
# No HDU found matching: OBS_ID = 81868, HDU_TYPE = bkg, HDU_CLASS = None

# %%
# Reconstructed and true energy axis
energy_axis = MapAxis.from_energy_bounds(0.350, 20, 20, unit= "TeV", name="energy")


energy_axis_true = MapAxis.from_energy_bounds(0.100, 50, 20, unit= "TeV", name="energy_true")


target_position = SkyCoord(ra="19h59m59.8s",dec="+65d08m55s", frame="icrs")
#print(target_position)-> In (299.99916667, 65.14861111)

on_radius=Angle("0.11 deg")
on_region= CircleSkyRegion(center=target_position,radius=on_radius)

# %%
geom = WcsGeom.create(skydir=target_position, binsz=0.02, width="7 deg", proj="CAR")
geom_image = geom.to_image()
# IS THERE AN EXCLUSION REGION ASIDE FROM THE CENTER???
center_region = CircleSkyRegion(center=target_position, radius=0.35 * u.deg)
exclusion_mask=Map.from_geom(geom_image)
exclusion_mask.data=geom_image.region_mask([center_region], inside=False)
#exclusion_mask.sum_over_axes().plot(add_cbar=True)


bkg_maker = ReflectedRegionsBackgroundMaker(exclusion_mask=exclusion_mask)

#Create a Safe_mask_maker
safe_mask_maker = SafeMaskMaker(methods=["aeff-default", "offset-max"], offset_max=2.5*u.deg)


dataset_empty = SpectrumDataset.create(
    e_reco=energy_axis, e_true=energy_axis_true, region=on_region, name="obs-0", reference_time="2010-12-02"
)
maker = SpectrumDatasetMaker(selection=["exposure", "psf", "edisp"])

# %%
# Define spectral model - a simple Power Law in this case
model_simu = PowerLawSpectralModel(
    index=3.0,
    amplitude=2.5e-12 * u.Unit("cm-2 s-1 TeV-1"),
    reference=1 * u.TeV,
)
#print(model_simu)
# we set the sky model used in the dataset
model = SkyModel(spectral_model=model_simu, name="source")

# %%
def load_irfs_new(filename):
    from gammapy.irf import EffectiveAreaTable2D, EnergyDispersion2D, PSF3D
    aeff = EffectiveAreaTable2D.read(filename, hdu="EFFECTIVE AREA")
    #bkg = Background3D.read(filename, hdu="BACKGROUND")
    edisp = EnergyDispersion2D.read(filename, hdu="ENERGY DISPERSION")
    psf = PSF3D.read(filename, hdu="PSF")

    return dict(aeff=aeff, edisp=edisp, psf=psf)

# %%
list_of_dataset = Datasets()
for obs in observations:
    dataset_empty = SpectrumDataset.create(
    e_reco=energy_axis, e_true=energy_axis_true, region=on_region, name=f"obs-{obs.obs_id}", reference_time="2010-12-02")
    irfs = load_irfs_new(f"/Users/cedrickperron/GAMMAPY/{source}/{obs.obs_id}.anasum.fits")
    livetime = obs.gti.time_delta[0]
    pointing = obs.fixed_pointing_info.radec
    obs = Observation.create(pointing=pointing, livetime=livetime, irfs=irfs)
    dataset = maker.run(dataset_empty.copy(), obs)
    dataset1 = safe_mask_maker.run(dataset_empty.copy(), obs)
    dataset.mask_safe = dataset1.mask_safe
    list_of_dataset.append(dataset)

# %%
for dataset in list_of_dataset:
    dataset.models = model
    dataset.fake(random_state=6)

# %%
list_of_dataset.info_table(cumulative=True)
# Out:
# <Table length=110>
#   name    counts background  excess ... n_fit_bins stat_type      stat_sum
#                                     ...
#   str8   float64  float64   float64 ...   int64       str4        float64
# -------- ------- ---------- ------- ... ---------- --------- ------------------
# RZvxhn8d    10.0        nan     nan ...         20      cash 24.077847547784543
# RZvxhn8d    21.0        nan     nan ...         20      cash  26.37680979423075
# RZvxhn8d    31.0        nan     nan ...         20      cash 30.249236944326388
# RZvxhn8d    41.0        nan     nan ...         20      cash  34.12166409442202
# RZvxhn8d    45.0        nan     nan ...         20      cash 38.559927018783256
# RZvxhn8d    62.0        nan     nan ...         20      cash  50.88787557633229
# RZvxhn8d    79.0        nan     nan ...         20      cash  63.21582413388133
# RZvxhn8d    96.0        nan     nan ...         20      cash   73.9730154151006
# RZvxhn8d   113.0        nan     nan ...         20      cash  86.30096397264964
#      ...     ...        ...     ... ...        ...       ...                ...
# RZvxhn8d  1915.0        nan     nan ...         20      cash  208.4470019708612
# RZvxhn8d  1926.0        nan     nan ...         20      cash 210.74596421730752
# RZvxhn8d  1937.0        nan     nan ...         20      cash  213.0449264637537
# RZvxhn8d  1941.0        nan     nan ...         20      cash  217.4831893881149
# RZvxhn8d  1945.0        nan     nan ...         20      cash 221.92145231247622
# RZvxhn8d  1965.0        nan     nan ...         20      cash 225.23195185884902
# RZvxhn8d  1973.0        nan     nan ...         20      cash 227.32317016301766
# RZvxhn8d  1995.0        nan     nan ...         20      cash  224.1273740597366
# RZvxhn8d  2006.0        nan     nan ...         20      cash 226.42633630618292
# RZvxhn8d  2049.0        nan     nan ...         20      cash  212.6780070270608
